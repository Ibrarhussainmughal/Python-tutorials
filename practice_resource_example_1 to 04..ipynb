# %%
import pandas as pd

# %%
data = pd.read_csv("example_1.csv")
data
# Out:
#       name  gender   age  oaths
# 0  Kaladin    Male  20.0    3.0
# 1  Shallan  Female  17.0    2.0
# 2  Dalinar    Male  53.0    3.0
# 3    Szeth    Male  35.0    0.0
# 4     Hoid    Male   NaN    NaN
# 5  Jashnah  Female  34.0    3.0

# %%
data = pd.read_csv("example_2.csv")
data
# Out:
#      name\tgender\tage\toaths
# 0    Kaladin\tMale\t20.0\t3.0
# 1  Shallan\tFemale\t17.0\t2.0
# 2    Dalinar\tMale\t53.0\t3.0
# 3      Szeth\tMale\t35.0\t0.0
# 4              Hoid\tMale\t\t
# 5  Jashnah\tFemale\t34.0\t3.0

# %%
data = pd.read_csv("example_2.csv", delim_whitespace=True)
data
# Out:
#       name  gender   age  oaths
# 0  Kaladin    Male  20.0    3.0
# 1  Shallan  Female  17.0    2.0
# 2  Dalinar    Male  53.0    3.0
# 3    Szeth    Male  35.0    0.0
# 4     Hoid    Male   NaN    NaN
# 5  Jashnah  Female  34.0    3.0

# %%
data = pd.read_csv("example_3.csv")
data
# Out:
#    Unnamed: 0     name  gender   age  oaths
# 0           0  Kaladin    Male  20.0    3.0
# 1           1  Shallan  Female  17.0    2.0
# 2           2  Dalinar    Male  53.0    3.0
# 3           3    Szeth    Male  35.0    0.0
# 4           4     Hoid    Male   NaN    NaN
# 5           5  Jashnah  Female  34.0    3.0

# %%
data = pd.read_csv("example_4.csv")
data
# Out:
#   # This file contains details guessed from Stormlight Archive
# 0                              name|gender|age|oaths
# 1                              Kaladin|Male|20.0|3.0
# 2                            Shallan|Female|17.0|2.0
# 3                              Dalinar|Male|53.0|3.0
# 4                                Szeth|Male|35.0|0.0
# 5                             # Who knows about Hoid
# 6                                  Hoid|Male|NaN|NaN
# 7                            Jashnah|Female|34.0|3.0

# %%
data = pd.read_csv("example_4.csv", sep="|", comment="#")
data
# Out:
#       name  gender   age  oaths
# 0  Kaladin    Male  20.0    3.0
# 1  Shallan  Female  17.0    2.0
# 2  Dalinar    Male  53.0    3.0
# 3    Szeth    Male  35.0    0.0
# 4     Hoid    Male   NaN    NaN
# 5  Jashnah  Female  34.0    3.0
